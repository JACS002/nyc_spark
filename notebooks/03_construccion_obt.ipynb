# %%
# -*- coding: utf-8 -*-
# Paso 3: Construcción del OBT_TRIPS limpio y consolidado
# - Toma ANALYTICS.STG_TRIPS_ENRICHED
# - Sanea tiempos, deduplica, crea features y carga en ANALYTICS.OBT_TRIPS (esquema rico)
# - Endurecido: descarta duraciones negativas/>48h, distancias imposibles y velocidades outlier
# - Idempotente vía TRIP_ID (HASH determinístico)
# - Opción A: sincronización total por mes/servicio (UPSERT + DELETE anti-join)
# -----------------------------------------------------------------------------

import os, time
from snowflake.snowpark import Session

# --- Conexión Snowflake ---
cfg = {
    "account":   os.getenv("SNOWFLAKE_ACCOUNT"),
    "user":      os.getenv("SNOWFLAKE_USER"),
    "password":  os.getenv("SNOWFLAKE_PASSWORD"),
    "role":      os.getenv("SNOWFLAKE_ROLE", "SYSADMIN"),
    "warehouse": os.getenv("SNOWFLAKE_WAREHOUSE"),
    "database":  os.getenv("SNOWFLAKE_DATABASE"),
}
session = Session.builder.configs(cfg).create()
print(f"✅ Conectado: {cfg['database']} (WH={cfg['warehouse']}, ROLE={cfg.get('role')})")

DB = cfg["database"]
AN_SCHEMA  = "ANALYTICS"
SOURCE_TABLE = f"{DB}.{AN_SCHEMA}.STG_TRIPS_ENRICHED"
OBT_TABLE    = f"{DB}.{AN_SCHEMA}.OBT_TRIPS"

# Asegura contexto
session.sql(f"USE DATABASE {DB}").collect()
session.sql(f"USE SCHEMA {AN_SCHEMA}").collect()
print("📍 Contexto:", session.sql("SELECT CURRENT_DATABASE() db, CURRENT_SCHEMA() sch").collect())

# --- Crea OBT si no existe ---
session.sql(f"""
CREATE TABLE IF NOT EXISTS {OBT_TABLE} (
  TRIP_ID               STRING,
  PICKUP_DATETIME       TIMESTAMP_NTZ,
  DROPOFF_DATETIME      TIMESTAMP_NTZ,
  PICKUP_DATE           DATE,
  PICKUP_HOUR           NUMBER(2,0),
  DROPOFF_DATE          DATE,
  DROPOFF_HOUR          NUMBER(2,0),
  DAY_OF_WEEK           NUMBER(1,0),
  YEAR                  NUMBER(4,0),
  MONTH                 NUMBER(2,0),
  SERVICE               STRING,
  PULOCATIONID          NUMBER(38,0),
  PU_BOROUGH            STRING,
  PU_ZONE               STRING,
  PU_SERVICE_ZONE       STRING,
  DOLOCATIONID          NUMBER(38,0),
  DO_BOROUGH            STRING,
  DO_ZONE               STRING,
  DO_SERVICE_ZONE       STRING,
  VENDORID              NUMBER(38,0),
  VENDOR_NAME           STRING,
  RATECODEID            NUMBER(38,0),
  RATE_DESC             STRING,
  PAYMENT_TYPE          NUMBER(38,0),
  PAYMENT_DESC          STRING,
  TRIP_TYPE             NUMBER(38,0),
  STORE_AND_FWD_FLAG    STRING,
  PASSENGER_COUNT       NUMBER(38,0),
  TRIP_DISTANCE         FLOAT,
  TRIP_DURATION_MIN     FLOAT,
  AVG_SPEED_MPH         FLOAT,
  FARE_AMOUNT           FLOAT,
  EXTRA                 FLOAT,
  MTA_TAX               FLOAT,
  TIP_AMOUNT            FLOAT,
  TOLLS_AMOUNT          FLOAT,
  IMPROVEMENT_SURCHARGE FLOAT,
  CONGESTION_SURCHARGE  FLOAT,
  AIRPORT_FEE           FLOAT,
  CBD_CONGESTION_FEE    FLOAT,
  TOTAL_AMOUNT          FLOAT,
  TIP_PCT               FLOAT,
  RUN_ID                STRING,
  BUILT_AT_UTC          TIMESTAMP_NTZ,
  INGESTED_AT_UTC       TIMESTAMP_NTZ,
  SOURCE_SERVICE        STRING,
  SOURCE_YEAR           NUMBER(4,0),
  SOURCE_MONTH          NUMBER(2,0)
)
DATA_RETENTION_TIME_IN_DAYS = 1;
""").collect()
print("✅ OBT_TRIPS listo (o ya existía)")

# --- Alcance de ejecución ---
RUN_ALL = True  # ⇦ pon True para histórico completo
if RUN_ALL:
    services = ['yellow', 'green']
    years = list(range(2015, 2026))
    months = list(range(1, 13))
else:
    services = ['yellow', 'green']
    years = [2015]
    months = [1]

# --- Función de construcción mensual (endurecida y sincronizada) ---
def build_month(service: str, year: int, month: int) -> int:
    print(f"\n🧱 Armando OBT para {service} {year}-{str(month).zfill(2)}")

    # 1) Vista temporal con saneo, deduplicación y features
    sql_tmp = f"""
    CREATE OR REPLACE TEMP VIEW tmp_obt_src AS
    WITH base AS (
      SELECT *
      FROM {SOURCE_TABLE}
      WHERE SERVICE = '{service}' AND YEAR = {year} AND MONTH = {month}
    ),
    time_sanitized AS (
      SELECT *,
             CASE
               WHEN PICKUP_DATETIME IS NULL OR DROPOFF_DATETIME IS NULL THEN NULL
               WHEN DATEDIFF('hour', PICKUP_DATETIME, DROPOFF_DATETIME) < 0 THEN NULL
               WHEN DATEDIFF('hour', PICKUP_DATETIME, DROPOFF_DATETIME) > 48 THEN NULL
               ELSE DROPOFF_DATETIME
             END AS DO_CLEAN
      FROM base
    ),
    dedup AS (
      SELECT *,
             ROW_NUMBER() OVER (
               PARTITION BY SERVICE, YEAR, MONTH,
                            PICKUP_DATETIME, DO_CLEAN,
                            PULOCATIONID, DOLOCATIONID,
                            VENDORID, TOTAL_AMOUNT
               ORDER BY _ENRICHED_AT DESC
             ) AS rn
      FROM time_sanitized
    ),
    shaped AS (
      SELECT
        TO_VARCHAR(HASH(
          SERVICE, YEAR, MONTH,
          PICKUP_DATETIME, DO_CLEAN,
          PULOCATIONID, DOLOCATIONID,
          VENDORID, TOTAL_AMOUNT, RATECODEID
        ))                                              AS TRIP_ID,
        PICKUP_DATETIME,
        DO_CLEAN                                        AS DROPOFF_DATETIME,
        TO_DATE(PICKUP_DATETIME)                        AS PICKUP_DATE,
        EXTRACT(HOUR FROM PICKUP_DATETIME)::NUMBER(2,0) AS PICKUP_HOUR,
        TO_DATE(DO_CLEAN)                               AS DROPOFF_DATE,
        EXTRACT(HOUR FROM DO_CLEAN)::NUMBER(2,0)        AS DROPOFF_HOUR,
        EXTRACT(DOW  FROM PICKUP_DATETIME)::NUMBER(1,0) AS DAY_OF_WEEK,
        YEAR::NUMBER(4,0)                               AS YEAR,
        MONTH::NUMBER(2,0)                              AS MONTH,
        SERVICE,
        PULOCATIONID, PU_BOROUGH, PU_ZONE, PU_SERVICE_ZONE,
        DOLOCATIONID, DO_BOROUGH, DO_ZONE, DO_SERVICE_ZONE,
        VENDORID, VENDOR_NAME,
        RATECODEID, RATE_DESC,
        PAYMENT_TYPE, PAYMENT_DESC,
        TRIP_TYPE, STORE_AND_FWD_FLAG,
        PASSENGER_COUNT, TRIP_DISTANCE,
        CASE WHEN DO_CLEAN IS NOT NULL AND PICKUP_DATETIME IS NOT NULL
             THEN DATEDIFF('minute', PICKUP_DATETIME, DO_CLEAN)::FLOAT
             ELSE NULL END AS TRIP_DURATION_MIN,
        CASE
          WHEN DO_CLEAN IS NOT NULL AND PICKUP_DATETIME IS NOT NULL
               AND DATEDIFF('minute', PICKUP_DATETIME, DO_CLEAN) > 0
            THEN TRIP_DISTANCE / (DATEDIFF('minute', PICKUP_DATETIME, DO_CLEAN) / 60.0)
          ELSE NULL
        END AS AVG_SPEED_MPH,
        FARE_AMOUNT, EXTRA, MTA_TAX, TIP_AMOUNT, TOLLS_AMOUNT,
        IMPROVEMENT_SURCHARGE, CONGESTION_SURCHARGE, AIRPORT_FEE, CBD_CONGESTION_FEE,
        TOTAL_AMOUNT,
        CASE WHEN FARE_AMOUNT IS NOT NULL AND FARE_AMOUNT > 0
             THEN TIP_AMOUNT / FARE_AMOUNT ELSE NULL END AS TIP_PCT,
        _RUN_ID AS RUN_ID,
        CURRENT_TIMESTAMP() AS BUILT_AT_UTC,
        _ENRICHED_AT AS INGESTED_AT_UTC,
        SERVICE AS SOURCE_SERVICE,
        YEAR::NUMBER(4,0) AS SOURCE_YEAR,
        MONTH::NUMBER(2,0) AS SOURCE_MONTH
      FROM dedup
      WHERE rn = 1 AND DO_CLEAN IS NOT NULL
    ),
    filtered AS (
      SELECT *
      FROM shaped
      WHERE TRIP_DURATION_MIN BETWEEN 0 AND 48*60
        AND TRIP_DISTANCE > 0 AND TRIP_DISTANCE <= 150
        AND (AVG_SPEED_MPH IS NULL OR AVG_SPEED_MPH <= 100)
    )
    SELECT * FROM filtered;
    """
    session.sql(sql_tmp).collect()

    # 2) MERGE idempotente (UPSERT)
    merge_sql = f"""
    MERGE INTO {OBT_TABLE} AS tgt
    USING tmp_obt_src AS src
      ON tgt.TRIP_ID = src.TRIP_ID
    WHEN MATCHED THEN UPDATE SET
      tgt.PICKUP_DATETIME       = src.PICKUP_DATETIME,
      tgt.DROPOFF_DATETIME      = src.DROPOFF_DATETIME,
      tgt.PICKUP_DATE           = src.PICKUP_DATE,
      tgt.PICKUP_HOUR           = src.PICKUP_HOUR,
      tgt.DROPOFF_DATE          = src.DROPOFF_DATE,
      tgt.DROPOFF_HOUR          = src.DROPOFF_HOUR,
      tgt.DAY_OF_WEEK           = src.DAY_OF_WEEK,
      tgt.YEAR                  = src.YEAR,
      tgt.MONTH                 = src.MONTH,
      tgt.SERVICE               = src.SERVICE,
      tgt.PULOCATIONID          = src.PULOCATIONID,
      tgt.PU_BOROUGH            = src.PU_BOROUGH,
      tgt.PU_ZONE               = src.PU_ZONE,
      tgt.PU_SERVICE_ZONE       = src.PU_SERVICE_ZONE,
      tgt.DOLOCATIONID          = src.DOLOCATIONID,
      tgt.DO_BOROUGH            = src.DO_BOROUGH,
      tgt.DO_ZONE               = src.DO_ZONE,
      tgt.DO_SERVICE_ZONE       = src.DO_SERVICE_ZONE,
      tgt.VENDORID              = src.VENDORID,
      tgt.VENDOR_NAME           = src.VENDOR_NAME,
      tgt.RATECODEID            = src.RATECODEID,
      tgt.RATE_DESC             = src.RATE_DESC,
      tgt.PAYMENT_TYPE          = src.PAYMENT_TYPE,
      tgt.PAYMENT_DESC          = src.PAYMENT_DESC,
      tgt.TRIP_TYPE             = src.TRIP_TYPE,
      tgt.STORE_AND_FWD_FLAG    = src.STORE_AND_FWD_FLAG,
      tgt.PASSENGER_COUNT       = src.PASSENGER_COUNT,
      tgt.TRIP_DISTANCE         = src.TRIP_DISTANCE,
      tgt.TRIP_DURATION_MIN     = src.TRIP_DURATION_MIN,
      tgt.AVG_SPEED_MPH         = src.AVG_SPEED_MPH,
      tgt.FARE_AMOUNT           = src.FARE_AMOUNT,
      tgt.EXTRA                 = src.EXTRA,
      tgt.MTA_TAX               = src.MTA_TAX,
      tgt.TIP_AMOUNT            = src.TIP_AMOUNT,
      tgt.TOLLS_AMOUNT          = src.TOLLS_AMOUNT,
      tgt.IMPROVEMENT_SURCHARGE = src.IMPROVEMENT_SURCHARGE,
      tgt.CONGESTION_SURCHARGE  = src.CONGESTION_SURCHARGE,
      tgt.AIRPORT_FEE           = src.AIRPORT_FEE,
      tgt.CBD_CONGESTION_FEE    = src.CBD_CONGESTION_FEE,
      tgt.TOTAL_AMOUNT          = src.TOTAL_AMOUNT,
      tgt.TIP_PCT               = src.TIP_PCT,
      tgt.RUN_ID                = src.RUN_ID,
      tgt.BUILT_AT_UTC          = src.BUILT_AT_UTC,
      tgt.INGESTED_AT_UTC       = src.INGESTED_AT_UTC,
      tgt.SOURCE_SERVICE        = src.SOURCE_SERVICE,
      tgt.SOURCE_YEAR           = src.SOURCE_YEAR,
      tgt.SOURCE_MONTH          = src.SOURCE_MONTH
    WHEN NOT MATCHED THEN INSERT (
      TRIP_ID, PICKUP_DATETIME, DROPOFF_DATETIME,
      PICKUP_DATE, PICKUP_HOUR, DROPOFF_DATE, DROPOFF_HOUR,
      DAY_OF_WEEK, YEAR, MONTH, SERVICE,
      PULOCATIONID, PU_BOROUGH, PU_ZONE, PU_SERVICE_ZONE,
      DOLOCATIONID, DO_BOROUGH, DO_ZONE, DO_SERVICE_ZONE,
      VENDORID, VENDOR_NAME, RATECODEID, RATE_DESC,
      PAYMENT_TYPE, PAYMENT_DESC, TRIP_TYPE, STORE_AND_FWD_FLAG,
      PASSENGER_COUNT, TRIP_DISTANCE, TRIP_DURATION_MIN, AVG_SPEED_MPH,
      FARE_AMOUNT, EXTRA, MTA_TAX, TIP_AMOUNT, TOLLS_AMOUNT,
      IMPROVEMENT_SURCHARGE, CONGESTION_SURCHARGE, AIRPORT_FEE, CBD_CONGESTION_FEE,
      TOTAL_AMOUNT, TIP_PCT,
      RUN_ID, BUILT_AT_UTC, INGESTED_AT_UTC,
      SOURCE_SERVICE, SOURCE_YEAR, SOURCE_MONTH
    ) VALUES (
      src.TRIP_ID, src.PICKUP_DATETIME, src.DROPOFF_DATETIME,
      src.PICKUP_DATE, src.PICKUP_HOUR, src.DROPOFF_DATE, src.DROPOFF_HOUR,
      src.DAY_OF_WEEK, src.YEAR, src.MONTH, src.SERVICE,
      src.PULOCATIONID, src.PU_BOROUGH, src.PU_ZONE, src.PU_SERVICE_ZONE,
      src.DOLOCATIONID, src.DO_BOROUGH, src.DO_ZONE, src.DO_SERVICE_ZONE,
      src.VENDORID, src.VENDOR_NAME, src.RATECODEID, src.RATE_DESC,
      src.PAYMENT_TYPE, src.PAYMENT_DESC, src.TRIP_TYPE, src.STORE_AND_FWD_FLAG,
      src.PASSENGER_COUNT, src.TRIP_DISTANCE, src.TRIP_DURATION_MIN, src.AVG_SPEED_MPH,
      src.FARE_AMOUNT, src.EXTRA, src.MTA_TAX, src.TIP_AMOUNT, src.TOLLS_AMOUNT,
      src.IMPROVEMENT_SURCHARGE, src.CONGESTION_SURCHARGE, src.AIRPORT_FEE, src.CBD_CONGESTION_FEE,
      src.TOTAL_AMOUNT, src.TIP_PCT,
      src.RUN_ID, src.BUILT_AT_UTC, src.INGESTED_AT_UTC,
      src.SOURCE_SERVICE, src.SOURCE_YEAR, src.SOURCE_MONTH
    );
    """
    session.sql(merge_sql).collect()

    # 3) DELETE anti-join: elimina del OBT lo que no esté en la vista del mes/servicio
    delete_sql = f"""
    DELETE FROM {OBT_TABLE}
    WHERE SERVICE = '{service}' AND YEAR = {year} AND MONTH = {month}
      AND TRIP_ID NOT IN (SELECT TRIP_ID FROM tmp_obt_src);
    """
    session.sql(delete_sql).collect()

    # 4) Conteo final
    cnt = session.sql(f"""
      SELECT COUNT(*) AS C
      FROM {OBT_TABLE}
      WHERE SERVICE='{service}' AND YEAR={year} AND MONTH={month}
    """).collect()[0]['C']
    print(f"✅ OBT filas {service} {year}-{str(month).zfill(2)}: {cnt:,}")
    return int(cnt)

# --- Ejecución controlada ---
summary = []
t0 = time.time()
for s in services:
    for y in years:
        for m in months:
            summary.append((s, y, m, build_month(s, y, m)))

print(f"\n🏁 Paso 3 listo en {time.time()-t0:,.1f}s")
summary
# Out:
# ✅ Conectado: NYC_TAXI_DM (WH=COMPUTE_WH, ROLE=ACCOUNTADMIN)
# 📍 Contexto: [Row(DB='NYC_TAXI_DM', SCH='ANALYTICS')]
# ✅ OBT_TRIPS listo (o ya existía)
#
# 🧱 Armando OBT para yellow 2015-01
# ✅ OBT filas yellow 2015-01: 12,665,073
#
# 🧱 Armando OBT para yellow 2015-02
# ✅ OBT filas yellow 2015-02: 12,368,347
#
# 🧱 Armando OBT para yellow 2015-03
# ✅ OBT filas yellow 2015-03: 13,260,358
#
# 🧱 Armando OBT para yellow 2015-04
# ✅ OBT filas yellow 2015-04: 12,984,370
#
# 🧱 Armando OBT para yellow 2015-05
# ✅ OBT filas yellow 2015-05: 13,073,844
#
# 🧱 Armando OBT para yellow 2015-06
# ✅ OBT filas yellow 2015-06: 12,246,555
#
# 🧱 Armando OBT para yellow 2015-07
# ✅ OBT filas yellow 2015-07: 11,486,184
#
# 🧱 Armando OBT para yellow 2015-08
# ✅ OBT filas yellow 2015-08: 11,052,998
#
# 🧱 Armando OBT para yellow 2015-09
# ✅ OBT filas yellow 2015-09: 11,145,256
#
# 🧱 Armando OBT para yellow 2015-10
# ✅ OBT filas yellow 2015-10: 12,230,107
#
# 🧱 Armando OBT para yellow 2015-11
# ✅ OBT filas yellow 2015-11: 11,233,020
#
# 🧱 Armando OBT para yellow 2015-12
# ✅ OBT filas yellow 2015-12: 11,381,903
#
# 🧱 Armando OBT para yellow 2016-01
# ✅ OBT filas yellow 2016-01: 10,839,922
#
# 🧱 Armando OBT para yellow 2016-02
# ✅ OBT filas yellow 2016-02: 11,309,845
#
# 🧱 Armando OBT para yellow 2016-03
# ✅ OBT filas yellow 2016-03: 12,134,694
#
# 🧱 Armando OBT para yellow 2016-04
# ✅ OBT filas yellow 2016-04: 11,852,134
#
# 🧱 Armando OBT para yellow 2016-05
# ✅ OBT filas yellow 2016-05: 11,761,002
#
# 🧱 Armando OBT para yellow 2016-06
# ✅ OBT filas yellow 2016-06: 11,062,584
#
# 🧱 Armando OBT para yellow 2016-07
# ✅ OBT filas yellow 2016-07: 10,229,093
#
# 🧱 Armando OBT para yellow 2016-08
# ✅ OBT filas yellow 2016-08: 9,880,010
#
# 🧱 Armando OBT para yellow 2016-09
# ✅ OBT filas yellow 2016-09: 10,051,282
#
# 🧱 Armando OBT para yellow 2016-10
# ✅ OBT filas yellow 2016-10: 10,786,656
#
# 🧱 Armando OBT para yellow 2016-11
# ✅ OBT filas yellow 2016-11: 10,036,731
#
# 🧱 Armando OBT para yellow 2016-12
# ✅ OBT filas yellow 2016-12: 10,379,864
#
# 🧱 Armando OBT para yellow 2017-01
# ✅ OBT filas yellow 2017-01: 9,649,991
#
# 🧱 Armando OBT para yellow 2017-02
# ✅ OBT filas yellow 2017-02: 9,110,089
#
# 🧱 Armando OBT para yellow 2017-03
# ✅ OBT filas yellow 2017-03: 10,226,585
#
# 🧱 Armando OBT para yellow 2017-04
# ✅ OBT filas yellow 2017-04: 9,977,078
#
# 🧱 Armando OBT para yellow 2017-05
# ✅ OBT filas yellow 2017-05: 10,033,630
#
# 🧱 Armando OBT para yellow 2017-06
# ✅ OBT filas yellow 2017-06: 9,590,198
#
# 🧱 Armando OBT para yellow 2017-07
# ✅ OBT filas yellow 2017-07: 8,527,130
#
# 🧱 Armando OBT para yellow 2017-08
# ✅ OBT filas yellow 2017-08: 8,363,276
#
# 🧱 Armando OBT para yellow 2017-09
# ✅ OBT filas yellow 2017-09: 8,882,629
#
# 🧱 Armando OBT para yellow 2017-10
# ✅ OBT filas yellow 2017-10: 9,701,224
#
# 🧱 Armando OBT para yellow 2017-11
# ✅ OBT filas yellow 2017-11: 9,220,702
#
# 🧱 Armando OBT para yellow 2017-12
# ✅ OBT filas yellow 2017-12: 9,446,834
#
# 🧱 Armando OBT para yellow 2018-01
# ✅ OBT filas yellow 2018-01: 8,703,617
#
# 🧱 Armando OBT para yellow 2018-02
# ✅ OBT filas yellow 2018-02: 8,439,005
#
# 🧱 Armando OBT para yellow 2018-03
# ✅ OBT filas yellow 2018-03: 9,368,525
#
# 🧱 Armando OBT para yellow 2018-04
# ✅ OBT filas yellow 2018-04: 9,246,676
#
# 🧱 Armando OBT para yellow 2018-05
# ✅ OBT filas yellow 2018-05: 9,163,647
#
# 🧱 Armando OBT para yellow 2018-06
# ✅ OBT filas yellow 2018-06: 8,652,734
#
# 🧱 Armando OBT para yellow 2018-07
# ✅ OBT filas yellow 2018-07: 7,793,626
#
# 🧱 Armando OBT para yellow 2018-08
# ✅ OBT filas yellow 2018-08: 7,798,264
#
# 🧱 Armando OBT para yellow 2018-09
# ✅ OBT filas yellow 2018-09: 7,989,615
#
# 🧱 Armando OBT para yellow 2018-10
# ✅ OBT filas yellow 2018-10: 8,763,307
#
# 🧱 Armando OBT para yellow 2018-11
# ✅ OBT filas yellow 2018-11: 8,093,316
#
# 🧱 Armando OBT para yellow 2018-12
# ✅ OBT filas yellow 2018-12: 8,132,174
#
# 🧱 Armando OBT para yellow 2019-01
# ✅ OBT filas yellow 2019-01: 7,640,184
#
# 🧱 Armando OBT para yellow 2019-02
# ✅ OBT filas yellow 2019-02: 6,998,300
#
# 🧱 Armando OBT para yellow 2019-03
# ✅ OBT filas yellow 2019-03: 7,808,907
#
# 🧱 Armando OBT para yellow 2019-04
# ✅ OBT filas yellow 2019-04: 7,423,408
#
# 🧱 Armando OBT para yellow 2019-05
# ✅ OBT filas yellow 2019-05: 7,540,394
#
# 🧱 Armando OBT para yellow 2019-06
# ✅ OBT filas yellow 2019-06: 6,906,867
#
# 🧱 Armando OBT para yellow 2019-07
# ✅ OBT filas yellow 2019-07: 6,241,363
#
# 🧱 Armando OBT para yellow 2019-08
# ✅ OBT filas yellow 2019-08: 6,002,862
#
# 🧱 Armando OBT para yellow 2019-09
# ✅ OBT filas yellow 2019-09: 6,495,092
#
# 🧱 Armando OBT para yellow 2019-10
# ✅ OBT filas yellow 2019-10: 7,142,454
#
# 🧱 Armando OBT para yellow 2019-11
# ✅ OBT filas yellow 2019-11: 6,802,749
#
# 🧱 Armando OBT para yellow 2019-12
# ✅ OBT filas yellow 2019-12: 6,822,167
#
# 🧱 Armando OBT para yellow 2020-01
# ✅ OBT filas yellow 2020-01: 6,321,491
#
# 🧱 Armando OBT para yellow 2020-02
# ✅ OBT filas yellow 2020-02: 6,237,710
#
# 🧱 Armando OBT para yellow 2020-03
# ✅ OBT filas yellow 2020-03: 2,975,534
#
# 🧱 Armando OBT para yellow 2020-04
# ✅ OBT filas yellow 2020-04: 230,104
#
# 🧱 Armando OBT para yellow 2020-05
# ✅ OBT filas yellow 2020-05: 334,861
#
# 🧱 Armando OBT para yellow 2020-06
# ✅ OBT filas yellow 2020-06: 526,201
#
# 🧱 Armando OBT para yellow 2020-07
# ✅ OBT filas yellow 2020-07: 769,095
#
# 🧱 Armando OBT para yellow 2020-08
# ✅ OBT filas yellow 2020-08: 970,749
#
# 🧱 Armando OBT para yellow 2020-09
# ✅ OBT filas yellow 2020-09: 1,306,794
#
# 🧱 Armando OBT para yellow 2020-10
# ✅ OBT filas yellow 2020-10: 1,634,468
#
# 🧱 Armando OBT para yellow 2020-11
# ✅ OBT filas yellow 2020-11: 1,476,948
#
# 🧱 Armando OBT para yellow 2020-12
# ✅ OBT filas yellow 2020-12: 1,444,278
#
# 🧱 Armando OBT para yellow 2021-01
# ✅ OBT filas yellow 2021-01: 1,349,576
#
# 🧱 Armando OBT para yellow 2021-02
# ✅ OBT filas yellow 2021-02: 1,352,620
#
# 🧱 Armando OBT para yellow 2021-03
# ✅ OBT filas yellow 2021-03: 1,900,325
#
# 🧱 Armando OBT para yellow 2021-04
# ✅ OBT filas yellow 2021-04: 2,139,190
#
# 🧱 Armando OBT para yellow 2021-05
# ✅ OBT filas yellow 2021-05: 2,472,917
#
# 🧱 Armando OBT para yellow 2021-06
# ✅ OBT filas yellow 2021-06: 2,798,769
#
# 🧱 Armando OBT para yellow 2021-07
# ✅ OBT filas yellow 2021-07: 2,783,216
#
# 🧱 Armando OBT para yellow 2021-08
# ✅ OBT filas yellow 2021-08: 2,750,016
#
# 🧱 Armando OBT para yellow 2021-09
# ✅ OBT filas yellow 2021-09: 2,906,490
#
# 🧱 Armando OBT para yellow 2021-10
# ✅ OBT filas yellow 2021-10: 3,419,481
#
# 🧱 Armando OBT para yellow 2021-11
# ✅ OBT filas yellow 2021-11: 3,435,794
#
# 🧱 Armando OBT para yellow 2021-12
# ✅ OBT filas yellow 2021-12: 3,176,242
#
# 🧱 Armando OBT para yellow 2022-01
# ✅ OBT filas yellow 2022-01: 2,433,861
#
# 🧱 Armando OBT para yellow 2022-02
# ✅ OBT filas yellow 2022-02: 2,946,436
#
# 🧱 Armando OBT para yellow 2022-03
# ✅ OBT filas yellow 2022-03: 3,585,822
#
# 🧱 Armando OBT para yellow 2022-04
# ✅ OBT filas yellow 2022-04: 3,558,314
#
# 🧱 Armando OBT para yellow 2022-05
# ✅ OBT filas yellow 2022-05: 3,540,971
#
# 🧱 Armando OBT para yellow 2022-06
# ✅ OBT filas yellow 2022-06: 3,504,695
#
# 🧱 Armando OBT para yellow 2022-07
# ✅ OBT filas yellow 2022-07: 3,128,031
#
# 🧱 Armando OBT para yellow 2022-08
# ✅ OBT filas yellow 2022-08: 3,103,109
#
# 🧱 Armando OBT para yellow 2022-09
# ✅ OBT filas yellow 2022-09: 3,131,075
#
# 🧱 Armando OBT para yellow 2022-10
# ✅ OBT filas yellow 2022-10: 3,612,410
#
# 🧱 Armando OBT para yellow 2022-11
# ✅ OBT filas yellow 2022-11: 3,191,900
#
# 🧱 Armando OBT para yellow 2022-12
# ✅ OBT filas yellow 2022-12: 3,336,181
#
# 🧱 Armando OBT para yellow 2023-01
# ✅ OBT filas yellow 2023-01: 3,020,456
#
# 🧱 Armando OBT para yellow 2023-02
# ✅ OBT filas yellow 2023-02: 2,872,422
#
# 🧱 Armando OBT para yellow 2023-03
# ✅ OBT filas yellow 2023-03: 3,354,690
#
# 🧱 Armando OBT para yellow 2023-04
# ✅ OBT filas yellow 2023-04: 3,247,495
#
# 🧱 Armando OBT para yellow 2023-05
# ✅ OBT filas yellow 2023-05: 3,466,186
#
# 🧱 Armando OBT para yellow 2023-06
# ✅ OBT filas yellow 2023-06: 3,259,264
#
# 🧱 Armando OBT para yellow 2023-07
# ✅ OBT filas yellow 2023-07: 2,856,884
#
# 🧱 Armando OBT para yellow 2023-08
# ✅ OBT filas yellow 2023-08: 2,766,385
#
# 🧱 Armando OBT para yellow 2023-09
# ✅ OBT filas yellow 2023-09: 2,747,788
#
# 🧱 Armando OBT para yellow 2023-10
# ✅ OBT filas yellow 2023-10: 3,400,224
#
# 🧱 Armando OBT para yellow 2023-11
# ✅ OBT filas yellow 2023-11: 3,236,067
#
# 🧱 Armando OBT para yellow 2023-12
# ✅ OBT filas yellow 2023-12: 3,302,848
#
# 🧱 Armando OBT para yellow 2024-01
# ✅ OBT filas yellow 2024-01: 2,903,956
#
# 🧱 Armando OBT para yellow 2024-02
# ✅ OBT filas yellow 2024-02: 2,939,040
#
# 🧱 Armando OBT para yellow 2024-03
# ✅ OBT filas yellow 2024-03: 3,495,138
#
# 🧱 Armando OBT para yellow 2024-04
# ✅ OBT filas yellow 2024-04: 3,468,116
#
# 🧱 Armando OBT para yellow 2024-05
# ✅ OBT filas yellow 2024-05: 3,673,662
#
# 🧱 Armando OBT para yellow 2024-06
# ✅ OBT filas yellow 2024-06: 3,485,793
#
# 🧱 Armando OBT para yellow 2024-07
# ✅ OBT filas yellow 2024-07: 3,028,447
#
# 🧱 Armando OBT para yellow 2024-08
# ✅ OBT filas yellow 2024-08: 2,921,348
#
# 🧱 Armando OBT para yellow 2024-09
# ✅ OBT filas yellow 2024-09: 3,551,417
#
# 🧱 Armando OBT para yellow 2024-10
# ✅ OBT filas yellow 2024-10: 3,751,667
#
# 🧱 Armando OBT para yellow 2024-11
# ✅ OBT filas yellow 2024-11: 3,576,651
#
# 🧱 Armando OBT para yellow 2024-12
# ✅ OBT filas yellow 2024-12: 3,592,558
#
# 🧱 Armando OBT para yellow 2025-01
# ✅ OBT filas yellow 2025-01: 3,383,958
#
# 🧱 Armando OBT para yellow 2025-02
# ✅ OBT filas yellow 2025-02: 3,477,392
#
# 🧱 Armando OBT para yellow 2025-03
# ✅ OBT filas yellow 2025-03: 4,041,081
#
# 🧱 Armando OBT para yellow 2025-04
# ✅ OBT filas yellow 2025-04: 3,878,635
#
# 🧱 Armando OBT para yellow 2025-05
# ✅ OBT filas yellow 2025-05: 4,450,106
#
# 🧱 Armando OBT para yellow 2025-06
# ✅ OBT filas yellow 2025-06: 4,187,530
#
# 🧱 Armando OBT para yellow 2025-07
# ✅ OBT filas yellow 2025-07: 3,774,761
#
# 🧱 Armando OBT para yellow 2025-08
# ✅ OBT filas yellow 2025-08: 3,468,430
#
# 🧱 Armando OBT para yellow 2025-09
# ✅ OBT filas yellow 2025-09: 0
#
# 🧱 Armando OBT para yellow 2025-10
# ✅ OBT filas yellow 2025-10: 0
#
# 🧱 Armando OBT para yellow 2025-11
# ✅ OBT filas yellow 2025-11: 0
#
# 🧱 Armando OBT para yellow 2025-12
# ✅ OBT filas yellow 2025-12: 0
#
# 🧱 Armando OBT para green 2015-01
# ✅ OBT filas green 2015-01: 1,484,806
#
# 🧱 Armando OBT para green 2015-02
# ✅ OBT filas green 2015-02: 1,552,334
#
# 🧱 Armando OBT para green 2015-03
# ✅ OBT filas green 2015-03: 1,695,794
#
# 🧱 Armando OBT para green 2015-04
# ✅ OBT filas green 2015-04: 1,638,461
#
# 🧱 Armando OBT para green 2015-05
# ✅ OBT filas green 2015-05: 1,759,620
#
# 🧱 Armando OBT para green 2015-06
# ✅ OBT filas green 2015-06: 1,614,686
#
# 🧱 Armando OBT para green 2015-07
# ✅ OBT filas green 2015-07: 1,519,027
#
# 🧱 Armando OBT para green 2015-08
# ✅ OBT filas green 2015-08: 1,510,904
#
# 🧱 Armando OBT para green 2015-09
# ✅ OBT filas green 2015-09: 1,473,560
#
# 🧱 Armando OBT para green 2015-10
# ✅ OBT filas green 2015-10: 1,607,795
#
# 🧱 Armando OBT para green 2015-11
# ✅ OBT filas green 2015-11: 1,507,828
#
# 🧱 Armando OBT para green 2015-12
# ✅ OBT filas green 2015-12: 1,585,449
#
# 🧱 Armando OBT para green 2016-01
# ✅ OBT filas green 2016-01: 1,424,047
#
# 🧱 Armando OBT para green 2016-02
# ✅ OBT filas green 2016-02: 1,491,046
#
# 🧱 Armando OBT para green 2016-03
# ✅ OBT filas green 2016-03: 1,555,389
#
# 🧱 Armando OBT para green 2016-04
# ✅ OBT filas green 2016-04: 1,522,759
#
# 🧱 Armando OBT para green 2016-05
# ✅ OBT filas green 2016-05: 1,516,543
#
# 🧱 Armando OBT para green 2016-06
# ✅ OBT filas green 2016-06: 1,385,060
#
# 🧱 Armando OBT para green 2016-07
# ✅ OBT filas green 2016-07: 1,312,591
#
# 🧱 Armando OBT para green 2016-08
# ✅ OBT filas green 2016-08: 1,228,833
#
# 🧱 Armando OBT para green 2016-09
# ✅ OBT filas green 2016-09: 1,145,769
#
# 🧱 Armando OBT para green 2016-10
# ✅ OBT filas green 2016-10: 1,236,466
#
# 🧱 Armando OBT para green 2016-11
# ✅ OBT filas green 2016-11: 1,132,574
#
# 🧱 Armando OBT para green 2016-12
# ✅ OBT filas green 2016-12: 1,208,395
#
# 🧱 Armando OBT para green 2017-01
# ✅ OBT filas green 2017-01: 1,056,050
#
# 🧱 Armando OBT para green 2017-02
# ✅ OBT filas green 2017-02: 1,009,184
#
# 🧱 Armando OBT para green 2017-03
# ✅ OBT filas green 2017-03: 1,144,095
#
# 🧱 Armando OBT para green 2017-04
# ✅ OBT filas green 2017-04: 1,067,923
#
# 🧱 Armando OBT para green 2017-05
# ✅ OBT filas green 2017-05: 1,046,980
#
# 🧱 Armando OBT para green 2017-06
# ✅ OBT filas green 2017-06: 964,555
#
# 🧱 Armando OBT para green 2017-07
# ✅ OBT filas green 2017-07: 903,722
#
# 🧱 Armando OBT para green 2017-08
# ✅ OBT filas green 2017-08: 857,295
#
# 🧱 Armando OBT para green 2017-09
# ✅ OBT filas green 2017-09: 872,770
#
# 🧱 Armando OBT para green 2017-10
# ✅ OBT filas green 2017-10: 915,244
#
# 🧱 Armando OBT para green 2017-11
# ✅ OBT filas green 2017-11: 863,843
#
# 🧱 Armando OBT para green 2017-12
# ✅ OBT filas green 2017-12: 895,504
#
# 🧱 Armando OBT para green 2018-01
# ✅ OBT filas green 2018-01: 783,319
#
# 🧱 Armando OBT para green 2018-02
# ✅ OBT filas green 2018-02: 761,276
#
# 🧱 Armando OBT para green 2018-03
# ✅ OBT filas green 2018-03: 827,214
#
# 🧱 Armando OBT para green 2018-04
# ✅ OBT filas green 2018-04: 790,208
#
# 🧱 Armando OBT para green 2018-05
# ✅ OBT filas green 2018-05: 786,556
#
# 🧱 Armando OBT para green 2018-06
# ✅ OBT filas green 2018-06: 730,071
#
# 🧱 Armando OBT para green 2018-07
# ✅ OBT filas green 2018-07: 676,326
#
# 🧱 Armando OBT para green 2018-08
# ✅ OBT filas green 2018-08: 667,679
#
# 🧱 Armando OBT para green 2018-09
# ✅ OBT filas green 2018-09: 674,101
#
# 🧱 Armando OBT para green 2018-10
# ✅ OBT filas green 2018-10: 722,944
#
# 🧱 Armando OBT para green 2018-11
# ✅ OBT filas green 2018-11: 664,978
#
# 🧱 Armando OBT para green 2018-12
# ✅ OBT filas green 2018-12: 708,842
#
# 🧱 Armando OBT para green 2019-01
# ✅ OBT filas green 2019-01: 660,831
#
# 🧱 Armando OBT para green 2019-02
# ✅ OBT filas green 2019-02: 604,920
#
# 🧱 Armando OBT para green 2019-03
# ✅ OBT filas green 2019-03: 632,258
#
# 🧱 Armando OBT para green 2019-04
# ✅ OBT filas green 2019-04: 558,384
#
# 🧱 Armando OBT para green 2019-05
# ✅ OBT filas green 2019-05: 536,038
#
# 🧱 Armando OBT para green 2019-06
# ✅ OBT filas green 2019-06: 496,758
#
# 🧱 Armando OBT para green 2019-07
# ✅ OBT filas green 2019-07: 458,697
#
# 🧱 Armando OBT para green 2019-08
# ✅ OBT filas green 2019-08: 435,510
#
# 🧱 Armando OBT para green 2019-09
# ✅ OBT filas green 2019-09: 435,470
#
# 🧱 Armando OBT para green 2019-10
# ✅ OBT filas green 2019-10: 463,254
#
# 🧱 Armando OBT para green 2019-11
# ✅ OBT filas green 2019-11: 420,897
#
# 🧱 Armando OBT para green 2019-12
# ✅ OBT filas green 2019-12: 438,621
#
# 🧱 Armando OBT para green 2020-01
# ✅ OBT filas green 2020-01: 430,645
#
# 🧱 Armando OBT para green 2020-02
# ✅ OBT filas green 2020-02: 385,537
#
# 🧱 Armando OBT para green 2020-03
# ✅ OBT filas green 2020-03: 215,530
#
# 🧱 Armando OBT para green 2020-04
# ✅ OBT filas green 2020-04: 33,860
#
# 🧱 Armando OBT para green 2020-05
# ✅ OBT filas green 2020-05: 54,959
#
# 🧱 Armando OBT para green 2020-06
# ✅ OBT filas green 2020-06: 60,077
#
# 🧱 Armando OBT para green 2020-07
# ✅ OBT filas green 2020-07: 68,262
#
# 🧱 Armando OBT para green 2020-08
# ✅ OBT filas green 2020-08: 76,947
#
# 🧱 Armando OBT para green 2020-09
# ✅ OBT filas green 2020-09: 84,170
#
# 🧱 Armando OBT para green 2020-10
# ✅ OBT filas green 2020-10: 91,338
#
# 🧱 Armando OBT para green 2020-11
# ✅ OBT filas green 2020-11: 85,475
#
# 🧱 Armando OBT para green 2020-12
# ✅ OBT filas green 2020-12: 80,851
#
# 🧱 Armando OBT para green 2021-01
# ✅ OBT filas green 2021-01: 73,874
#
# 🧱 Armando OBT para green 2021-02
# ✅ OBT filas green 2021-02: 62,471
#
# 🧱 Armando OBT para green 2021-03
# ✅ OBT filas green 2021-03: 81,031
#
# 🧱 Armando OBT para green 2021-04
# ✅ OBT filas green 2021-04: 83,361
#
# 🧱 Armando OBT para green 2021-05
# ✅ OBT filas green 2021-05: 83,905
#
# 🧱 Armando OBT para green 2021-06
# ✅ OBT filas green 2021-06: 82,854
#
# 🧱 Armando OBT para green 2021-07
# ✅ OBT filas green 2021-07: 79,984
#
# 🧱 Armando OBT para green 2021-08
# ✅ OBT filas green 2021-08: 80,257
#
# 🧱 Armando OBT para green 2021-09
# ✅ OBT filas green 2021-09: 91,734
#
# 🧱 Armando OBT para green 2021-10
# ✅ OBT filas green 2021-10: 106,282
#
# 🧱 Armando OBT para green 2021-11
# ✅ OBT filas green 2021-11: 104,194
#
# 🧱 Armando OBT para green 2021-12
# ✅ OBT filas green 2021-12: 95,842
#
# 🧱 Armando OBT para green 2022-01
# ✅ OBT filas green 2022-01: 58,816
#
# 🧱 Armando OBT para green 2022-02
# ✅ OBT filas green 2022-02: 65,565
#
# 🧱 Armando OBT para green 2022-03
# ✅ OBT filas green 2022-03: 74,048
#
# 🧱 Armando OBT para green 2022-04
# ✅ OBT filas green 2022-04: 72,107
#
# 🧱 Armando OBT para green 2022-05
# ✅ OBT filas green 2022-05: 72,257
#
# 🧱 Armando OBT para green 2022-06
# ✅ OBT filas green 2022-06: 68,796
#
# 🧱 Armando OBT para green 2022-07
# ✅ OBT filas green 2022-07: 59,706
#
# 🧱 Armando OBT para green 2022-08
# ✅ OBT filas green 2022-08: 61,254
#
# 🧱 Armando OBT para green 2022-09
# ✅ OBT filas green 2022-09: 64,665
#
# 🧱 Armando OBT para green 2022-10
# ✅ OBT filas green 2022-10: 65,291
#
# 🧱 Armando OBT para green 2022-11
# ✅ OBT filas green 2022-11: 58,919
#
# 🧱 Armando OBT para green 2022-12
# ✅ OBT filas green 2022-12: 68,395
#
# 🧱 Armando OBT para green 2023-01
# ✅ OBT filas green 2023-01: 64,800
#
# 🧱 Armando OBT para green 2023-02
# ✅ OBT filas green 2023-02: 61,890
#
# 🧱 Armando OBT para green 2023-03
# ✅ OBT filas green 2023-03: 68,575
#
# 🧱 Armando OBT para green 2023-04
# ✅ OBT filas green 2023-04: 62,239
#
# 🧱 Armando OBT para green 2023-05
# ✅ OBT filas green 2023-05: 65,683
#
# 🧱 Armando OBT para green 2023-06
# ✅ OBT filas green 2023-06: 62,113
#
# 🧱 Armando OBT para green 2023-07
# ✅ OBT filas green 2023-07: 57,921
#
# 🧱 Armando OBT para green 2023-08
# ✅ OBT filas green 2023-08: 57,275
#
# 🧱 Armando OBT para green 2023-09
# ✅ OBT filas green 2023-09: 62,231
#
# 🧱 Armando OBT para green 2023-10
# ✅ OBT filas green 2023-10: 62,448
#
# 🧱 Armando OBT para green 2023-11
# ✅ OBT filas green 2023-11: 60,634
#
# 🧱 Armando OBT para green 2023-12
# ✅ OBT filas green 2023-12: 60,874
#
# 🧱 Armando OBT para green 2024-01
# ✅ OBT filas green 2024-01: 53,613
#
# 🧱 Armando OBT para green 2024-02
# ✅ OBT filas green 2024-02: 50,698
#
# 🧱 Armando OBT para green 2024-03
# ✅ OBT filas green 2024-03: 54,402
#
# 🧱 Armando OBT para green 2024-04
# ✅ OBT filas green 2024-04: 53,244
#
# 🧱 Armando OBT para green 2024-05
# ✅ OBT filas green 2024-05: 57,858
#
# 🧱 Armando OBT para green 2024-06
# ✅ OBT filas green 2024-06: 51,976
#
# 🧱 Armando OBT para green 2024-07
# ✅ OBT filas green 2024-07: 48,817
#
# 🧱 Armando OBT para green 2024-08
# ✅ OBT filas green 2024-08: 49,019
#
# 🧱 Armando OBT para green 2024-09
# ✅ OBT filas green 2024-09: 51,609
#
# 🧱 Armando OBT para green 2024-10
# ✅ OBT filas green 2024-10: 53,504
#
# 🧱 Armando OBT para green 2024-11
# ✅ OBT filas green 2024-11: 49,425
#
# 🧱 Armando OBT para green 2024-12
# ✅ OBT filas green 2024-12: 50,948
#
# 🧱 Armando OBT para green 2025-01
# ✅ OBT filas green 2025-01: 45,623
#
# 🧱 Armando OBT para green 2025-02
# ✅ OBT filas green 2025-02: 44,204
#
# 🧱 Armando OBT para green 2025-03
# ✅ OBT filas green 2025-03: 48,735
#
# 🧱 Armando OBT para green 2025-04
# ✅ OBT filas green 2025-04: 49,177
#
# 🧱 Armando OBT para green 2025-05
# ✅ OBT filas green 2025-05: 52,566
#
# 🧱 Armando OBT para green 2025-06
# ✅ OBT filas green 2025-06: 47,541
#
# 🧱 Armando OBT para green 2025-07
# ✅ OBT filas green 2025-07: 46,639
#
# 🧱 Armando OBT para green 2025-08
# ✅ OBT filas green 2025-08: 44,788
#
# 🧱 Armando OBT para green 2025-09
# ✅ OBT filas green 2025-09: 0
#
# 🧱 Armando OBT para green 2025-10
# ✅ OBT filas green 2025-10: 0
#
# 🧱 Armando OBT para green 2025-11
# ✅ OBT filas green 2025-11: 0
#
# 🧱 Armando OBT para green 2025-12
# ✅ OBT filas green 2025-12: 0
#
# 🏁 Paso 3 listo en 6,212.0s
# [('yellow', 2015, 1, 12665073),
#  ('yellow', 2015, 2, 12368347),
#  ('yellow', 2015, 3, 13260358),
#  ('yellow', 2015, 4, 12984370),
#  ('yellow', 2015, 5, 13073844),
#  ('yellow', 2015, 6, 12246555),
#  ('yellow', 2015, 7, 11486184),
#  ('yellow', 2015, 8, 11052998),
#  ('yellow', 2015, 9, 11145256),
#  ('yellow', 2015, 10, 12230107),
#  ('yellow', 2015, 11, 11233020),
#  ('yellow', 2015, 12, 11381903),
#  ('yellow', 2016, 1, 10839922),
#  ('yellow', 2016, 2, 11309845),
#  ('yellow', 2016, 3, 12134694),
#  ('yellow', 2016, 4, 11852134),
#  ('yellow', 2016, 5, 11761002),
#  ('yellow', 2016, 6, 11062584),
#  ('yellow', 2016, 7, 10229093),
#  ('yellow', 2016, 8, 9880010),
#  ('yellow', 2016, 9, 10051282),
#  ('yellow', 2016, 10, 10786656),
#  ('yellow', 2016, 11, 10036731),
#  ('yellow', 2016, 12, 10379864),
#  ('yellow', 2017, 1, 9649991),
#  ('yellow', 2017, 2, 9110089),
#  ('yellow', 2017, 3, 10226585),
#  ('yellow', 2017, 4, 9977078),
#  ('yellow', 2017, 5, 10033630),
#  ('yellow', 2017, 6, 9590198),
#  ('yellow', 2017, 7, 8527130),
#  ('yellow', 2017, 8, 8363276),
#  ('yellow', 2017, 9, 8882629),
#  ('yellow', 2017, 10, 9701224),
#  ('yellow', 2017, 11, 9220702),
#  ('yellow', 2017, 12, 9446834),
#  ('yellow', 2018, 1, 8703617),
#  ('yellow', 2018, 2, 8439005),
#  ('yellow', 2018, 3, 9368525),
#  ('yellow', 2018, 4, 9246676),
#  ('yellow', 2018, 5, 9163647),
#  ('yellow', 2018, 6, 8652734),
#  ('yellow', 2018, 7, 7793626),
#  ('yellow', 2018, 8, 7798264),
#  ('yellow', 2018, 9, 7989615),
#  ('yellow', 2018, 10, 8763307),
#  ('yellow', 2018, 11, 8093316),
#  ('yellow', 2018, 12, 8132174),
#  ('yellow', 2019, 1, 7640184),
#  ('yellow', 2019, 2, 6998300),
#  ('yellow', 2019, 3, 7808907),
#  ('yellow', 2019, 4, 7423408),
#  ('yellow', 2019, 5, 7540394),
#  ('yellow', 2019, 6, 6906867),
#  ('yellow', 2019, 7, 6241363),
#  ('yellow', 2019, 8, 6002862),
#  ('yellow', 2019, 9, 6495092),
#  ('yellow', 2019, 10, 7142454),
#  ('yellow', 2019, 11, 6802749),
#  ('yellow', 2019, 12, 6822167),
#  ('yellow', 2020, 1, 6321491),
#  ('yellow', 2020, 2, 6237710),
#  ('yellow', 2020, 3, 2975534),
#  ('yellow', 2020, 4, 230104),
#  ('yellow', 2020, 5, 334861),
#  ('yellow', 2020, 6, 526201),
#  ('yellow', 2020, 7, 769095),
#  ('yellow', 2020, 8, 970749),
#  ('yellow', 2020, 9, 1306794),
#  ('yellow', 2020, 10, 1634468),
#  ('yellow', 2020, 11, 1476948),
#  ('yellow', 2020, 12, 1444278),
#  ('yellow', 2021, 1, 1349576),
#  ('yellow', 2021, 2, 1352620),
#  ('yellow', 2021, 3, 1900325),
#  ('yellow', 2021, 4, 2139190),
#  ('yellow', 2021, 5, 2472917),
#  ('yellow', 2021, 6, 2798769),
#  ('yellow', 2021, 7, 2783216),
#  ('yellow', 2021, 8, 2750016),
#  ('yellow', 2021, 9, 2906490),
#  ('yellow', 2021, 10, 3419481),
#  ('yellow', 2021, 11, 3435794),
#  ('yellow', 2021, 12, 3176242),
#  ('yellow', 2022, 1, 2433861),
#  ('yellow', 2022, 2, 2946436),
#  ('yellow', 2022, 3, 3585822),
#  ('yellow', 2022, 4, 3558314),
#  ('yellow', 2022, 5, 3540971),
#  ('yellow', 2022, 6, 3504695),
#  ('yellow', 2022, 7, 3128031),
#  ('yellow', 2022, 8, 3103109),
#  ('yellow', 2022, 9, 3131075),
#  ('yellow', 2022, 10, 3612410),
#  ('yellow', 2022, 11, 3191900),
#  ('yellow', 2022, 12, 3336181),
#  ('yellow', 2023, 1, 3020456),
#  ('yellow', 2023, 2, 2872422),
#  ('yellow', 2023, 3, 3354690),
#  ('yellow', 2023, 4, 3247495),
#  ('yellow', 2023, 5, 3466186),
#  ('yellow', 2023, 6, 3259264),
#  ('yellow', 2023, 7, 2856884),
#  ('yellow', 2023, 8, 2766385),
#  ('yellow', 2023, 9, 2747788),
#  ('yellow', 2023, 10, 3400224),
#  ('yellow', 2023, 11, 3236067),
#  ('yellow', 2023, 12, 3302848),
#  ('yellow', 2024, 1, 2903956),
#  ('yellow', 2024, 2, 2939040),
#  ('yellow', 2024, 3, 3495138),
#  ('yellow', 2024, 4, 3468116),
#  ('yellow', 2024, 5, 3673662),
#  ('yellow', 2024, 6, 3485793),
#  ('yellow', 2024, 7, 3028447),
#  ('yellow', 2024, 8, 2921348),
#  ('yellow', 2024, 9, 3551417),
#  ('yellow', 2024, 10, 3751667),
#  ('yellow', 2024, 11, 3576651),
#  ('yellow', 2024, 12, 3592558),
#  ('yellow', 2025, 1, 3383958),
#  ('yellow', 2025, 2, 3477392),
#  ('yellow', 2025, 3, 4041081),
#  ('yellow', 2025, 4, 3878635),
#  ('yellow', 2025, 5, 4450106),
#  ('yellow', 2025, 6, 4187530),
#  ('yellow', 2025, 7, 3774761),
#  ('yellow', 2025, 8, 3468430),
#  ('yellow', 2025, 9, 0),
#  ('yellow', 2025, 10, 0),
#  ('yellow', 2025, 11, 0),
#  ('yellow', 2025, 12, 0),
#  ('green', 2015, 1, 1484806),
#  ('green', 2015, 2, 1552334),
#  ('green', 2015, 3, 1695794),
#  ('green', 2015, 4, 1638461),
#  ('green', 2015, 5, 1759620),
#  ('green', 2015, 6, 1614686),
#  ('green', 2015, 7, 1519027),
#  ('green', 2015, 8, 1510904),
#  ('green', 2015, 9, 1473560),
#  ('green', 2015, 10, 1607795),
#  ('green', 2015, 11, 1507828),
#  ('green', 2015, 12, 1585449),
#  ('green', 2016, 1, 1424047),
#  ('green', 2016, 2, 1491046),
#  ('green', 2016, 3, 1555389),
#  ('green', 2016, 4, 1522759),
#  ('green', 2016, 5, 1516543),
#  ('green', 2016, 6, 1385060),
#  ('green', 2016, 7, 1312591),
#  ('green', 2016, 8, 1228833),
#  ('green', 2016, 9, 1145769),
#  ('green', 2016, 10, 1236466),
#  ('green', 2016, 11, 1132574),
#  ('green', 2016, 12, 1208395),
#  ('green', 2017, 1, 1056050),
#  ('green', 2017, 2, 1009184),
#  ('green', 2017, 3, 1144095),
#  ('green', 2017, 4, 1067923),
#  ('green', 2017, 5, 1046980),
#  ('green', 2017, 6, 964555),
#  ('green', 2017, 7, 903722),
#  ('green', 2017, 8, 857295),
#  ('green', 2017, 9, 872770),
#  ('green', 2017, 10, 915244),
#  ('green', 2017, 11, 863843),
#  ('green', 2017, 12, 895504),
#  ('green', 2018, 1, 783319),
#  ('green', 2018, 2, 761276),
#  ('green', 2018, 3, 827214),
#  ('green', 2018, 4, 790208),
#  ('green', 2018, 5, 786556),
#  ('green', 2018, 6, 730071),
#  ('green', 2018, 7, 676326),
#  ('green', 2018, 8, 667679),
#  ('green', 2018, 9, 674101),
#  ('green', 2018, 10, 722944),
#  ('green', 2018, 11, 664978),
#  ('green', 2018, 12, 708842),
#  ('green', 2019, 1, 660831),
#  ('green', 2019, 2, 604920),
#  ('green', 2019, 3, 632258),
#  ('green', 2019, 4, 558384),
#  ('green', 2019, 5, 536038),
#  ('green', 2019, 6, 496758),
#  ('green', 2019, 7, 458697),
#  ('green', 2019, 8, 435510),
#  ('green', 2019, 9, 435470),
#  ('green', 2019, 10, 463254),
#  ('green', 2019, 11, 420897),
#  ('green', 2019, 12, 438621),
#  ('green', 2020, 1, 430645),
#  ('green', 2020, 2, 385537),
#  ('green', 2020, 3, 215530),
#  ('green', 2020, 4, 33860),
#  ('green', 2020, 5, 54959),
#  ('green', 2020, 6, 60077),
#  ('green', 2020, 7, 68262),
#  ('green', 2020, 8, 76947),
#  ('green', 2020, 9, 84170),
#  ('green', 2020, 10, 91338),
#  ('green', 2020, 11, 85475),
#  ('green', 2020, 12, 80851),
#  ('green', 2021, 1, 73874),
#  ('green', 2021, 2, 62471),
#  ('green', 2021, 3, 81031),
#  ('green', 2021, 4, 83361),
#  ('green', 2021, 5, 83905),
#  ('green', 2021, 6, 82854),
#  ('green', 2021, 7, 79984),
#  ('green', 2021, 8, 80257),
#  ('green', 2021, 9, 91734),
#  ('green', 2021, 10, 106282),
#  ('green', 2021, 11, 104194),
#  ('green', 2021, 12, 95842),
#  ('green', 2022, 1, 58816),
#  ('green', 2022, 2, 65565),
#  ('green', 2022, 3, 74048),
#  ('green', 2022, 4, 72107),
#  ('green', 2022, 5, 72257),
#  ('green', 2022, 6, 68796),
#  ('green', 2022, 7, 59706),
#  ('green', 2022, 8, 61254),
#  ('green', 2022, 9, 64665),
#  ('green', 2022, 10, 65291),
#  ('green', 2022, 11, 58919),
#  ('green', 2022, 12, 68395),
#  ('green', 2023, 1, 64800),
#  ('green', 2023, 2, 61890),
#  ('green', 2023, 3, 68575),
#  ('green', 2023, 4, 62239),
#  ('green', 2023, 5, 65683),
#  ('green', 2023, 6, 62113),
#  ('green', 2023, 7, 57921),
#  ('green', 2023, 8, 57275),
#  ('green', 2023, 9, 62231),
#  ('green', 2023, 10, 62448),
#  ('green', 2023, 11, 60634),
#  ('green', 2023, 12, 60874),
#  ('green', 2024, 1, 53613),
#  ('green', 2024, 2, 50698),
#  ('green', 2024, 3, 54402),
#  ('green', 2024, 4, 53244),
#  ('green', 2024, 5, 57858),
#  ('green', 2024, 6, 51976),
#  ('green', 2024, 7, 48817),
#  ('green', 2024, 8, 49019),
#  ('green', 2024, 9, 51609),
#  ('green', 2024, 10, 53504),
#  ('green', 2024, 11, 49425),
#  ('green', 2024, 12, 50948),
#  ('green', 2025, 1, 45623),
#  ('green', 2025, 2, 44204),
#  ('green', 2025, 3, 48735),
#  ('green', 2025, 4, 49177),
#  ('green', 2025, 5, 52566),
#  ('green', 2025, 6, 47541),
#  ('green', 2025, 7, 46639),
#  ('green', 2025, 8, 44788),
#  ('green', 2025, 9, 0),
#  ('green', 2025, 10, 0),
#  ('green', 2025, 11, 0),
#  ('green', 2025, 12, 0)]
